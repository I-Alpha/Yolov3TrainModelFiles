# %%
'from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/mystic123/tensorflow-yolo-v3.git
# Out:
# Cloning into 'tensorflow-yolo-v3'...
# remote: Enumerating objects: 204, done.
# remote: Total 204 (delta 0), reused 0 (delta 0), pack-reused 204
# Receiving objects: 100% (204/204), 52.88 KiB | 595.00 KiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# %cd /content
# !cp /content/drive/My\ Drive/darknet/backup/yolo-obj_39000.weights /content/tensorflow-yolo-v3/yolov3.weights
# !cp /content/drive/My\ Drive/darknet/coco.names /content/tensorflow-yolo-v3/
# Out:
# /content

# %%
# %cd /content/tensorflow-yolo-v3
# !python convert_weights.py --class_names coco.names ----weights_file yolov3.weights
# !python convert_weights_pb.py
# Out:
# /content/tensorflow-yolo-v3
# WARNING: Logging before flag parsing goes to stderr.
# W0819 15:36:58.789200 139689577670528 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0819 15:36:58.793097 139689577670528 deprecation_wrapper.py:119] From convert_weights.py:52: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0819 15:36:58.793627 139689577670528 deprecation_wrapper.py:119] From convert_weights.py:34: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
#Prediction.... 

# !python ./demo.py --class_names "/content/tensorflow-yolo-v3/coco.names" --input_img "/content/drive/My Drive/darknet/test_images/2631.png" --output_img "/content/tensorflow-yolo-v3/Prediction.png" --frozen_model "/content/tensorflow-yolo-v3/frozen_darknet_yolov3_model.pb"
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 15:37:30.352885 139665312356224 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0819 15:37:30.354536 139665312356224 deprecation_wrapper.py:119] From ./demo.py:101: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0819 15:37:30.355011 139665312356224 deprecation_wrapper.py:119] From ./demo.py:46: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0819 15:37:30.355164 139665312356224 deprecation_wrapper.py:119] From ./demo.py:48: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# ...

# %%
# !cp /content/tensorflow-yolo-v3/frozen_darknet_yolov3_model.pb "/content/drive/My Drive/Colab Notebooks"
