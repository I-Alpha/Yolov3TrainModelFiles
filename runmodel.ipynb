# %%
# %matplotlib inline
import tensorflow as tf 
import numpy as np
import glob
from PIL import Image
import skimage.io
import skimage.segmentation
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
from __future__ import print_function

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# We're unzipping the cuDNN files from your Drive folder directly to the VM CUDA folders
# !tar -xzvf "/content/gdrive/My Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz" -C "/usr/local/"
# !chmod a+r /usr/local/cuda/include/cudnn.h

# Now we check the version we already installed. Can comment this line on future runs
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# %cd /content/gdrive/My\ Drive/darknet/
dos2unix /coco.data
# Out:
# /content/gdrive/My Drive/darknet
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fb8244253fbd> in <module>()
#       1 get_ipython().magic('cd /content/gdrive/My\\ Drive/darknet/')
# ----> 2 dos2unix /coco.data
#
# NameError: name 'dos2unix' is not defined

# %%
# Makes a dir for darknet and move there
#%cd /content
#!mkdir darknet



# Copy the Darkent compiled version to the VM local drive
#cp  "/content/gdrive/My Drive/darknet/bin/darknet/darknet" ./darknet

# %cd /content/darknet/
#Set execution permissions to Darknet
# !chmod +x ./darknet
# Out:
# /content/darknet

# %%
#Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# %cd /content/gdrive/My Drive/darknet/bin/darknet/
# !chmod +x ./darknet
! ./darknet detect "/content/gdrive/My Drive/darknet/cfg/yolov3.cfg" "yolov3.weights" "data/person.jpg" -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# /content/gdrive/My Drive/darknet/bin/darknet
# Couldn't open file: cfg/coco.data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-970058f048c0> in <module>()
#       4
#       5 # Show the result using the helper imgShow()
# ----> 6 imShow('predictions.jpg')
#
# NameError: name 'imShow' is not defined
